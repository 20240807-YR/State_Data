# %%
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("core3_degradation_hierarchical")

with mlflow.start_run(run_name="test_run"):
    mlflow.log_metric("test_metric", 1.0)

# %%
import mlflow
mlflow.search_runs(experiment_names=["core3_degradation_hierarchical"])
# Out:
#                              run_id experiment_id    status  \
# 0  6be1b29c9e074419873e00ccf44fb6de             1  FINISHED
# 1  03119862adee4a20bc7d9cb6cc6525de             1  FINISHED
# 2  5d9aba0bbbc14706b6ed9328eea191c9             1  FINISHED
# 3  dcc199f49b5e4a97ab0321c9bb24cd87             1  FINISHED
# 4  2f0fd3f31934409d9720434e1fa94817             1  FINISHED
# 5  b42f053a1f2d4487a24a8f0199160d25             1  FINISHED
# 6  007e708aaf9f4e3f914376293c226113             1  FINISHED
# 7  97b4afa71c4e4606bfc88883861db62b             1  FINISHED
#
#                                         artifact_uri  \
# 0  /Users/mac/Desktop/HW/State_Data/core_3/mlruns...
# 1  /Users/mac/Desktop/HW/State_Data/core_3/mlruns...
# 2  /Users/mac/Desktop/HW/State_Data/core_3/mlruns...
# 3  /Users/mac/Desktop/HW/State_Data/core_3/mlruns...
# 4  /Users/mac/Desktop/HW/State_Data/core_3/mlruns...
# 5  /Users/mac/Desktop/HW/State_Data/core_3/mlruns...
# 6  /Users/mac/Desktop/HW/State_Data/core_3/mlruns...
# 7  /Users/mac/Desktop/HW/State_Data/core_3/mlruns...
#
#                         start_time                         end_time  \
# 0 2025-12-25 18:56:53.032000+00:00 2025-12-25 18:56:53.045000+00:00
# 1 2025-12-25 18:54:33.342000+00:00 2025-12-25 18:54:33.353000+00:00
# 2 2025-12-25 18:53:28.514000+00:00 2025-12-25 18:53:29.902000+00:00
# 3 2025-12-25 18:53:13.613000+00:00 2025-12-25 18:53:28.487000+00:00
# 4 2025-12-25 18:53:11.783000+00:00 2025-12-25 18:53:13.605000+00:00
# 5 2025-12-25 18:36:07.918000+00:00 2025-12-25 18:36:09.416000+00:00
# 6 2025-12-25 18:35:51.104000+00:00 2025-12-25 18:36:07.889000+00:00
# 7 2025-12-25 18:35:49.354000+00:00 2025-12-25 18:35:51.095000+00:00
#
#    metrics.test_metric  metrics.error_std  metrics.val_MAE  metrics.val_RMSE  \
# 0                  1.0                NaN              NaN               NaN
# 1                  1.0                NaN              NaN               NaN
# 2                  NaN           1.593254         1.376787          1.686224
# 3                  NaN           0.207137         0.075242          0.207443
# 4                  NaN           0.192622         0.086880          0.198108
# 5                  NaN           1.635103         1.397089          1.726776
# 6                  NaN           0.208260         0.081378          0.210405
# 7                  NaN           0.192622         0.086880          0.198108
#
#    ... params.horizon params.model_type params.noise_sigma params.lookback  \
# 0  ...           None              None               None            None
# 1  ...           None              None               None            None
# 2  ...              7            linear                0.1              14
# 3  ...              7              lstm               None              14
# 4  ...              7            linear               None              14
# 5  ...              7            linear                0.1              14
# 6  ...              7              lstm               None              14
# 7  ...              7            linear               None              14
#
#   params.dataset params.stage tags.mlflow.source.type  \
# 0           None         None                   LOCAL
# 1           None         None                   LOCAL
# 2      synthetic            C                   LOCAL
# 3           nasa            A                   LOCAL
# 4           nasa            A                   LOCAL
# 5      synthetic            C                   LOCAL
# 6           nasa            A                   LOCAL
# 7           nasa            A                   LOCAL
#
#             tags.mlflow.runName  \
# 0                      test_run
# 1                      test_run
# 2  C_synth_linear_gap5_noise0p1
# 3                   A_nasa_lstm
# 4                 A_nasa_linear
# 5  C_synth_linear_gap5_noise0p1
# 6                   A_nasa_lstm
# 7                 A_nasa_linear
#
#                              tags.mlflow.source.name tags.mlflow.user
# 0  /Users/mac/Library/Python/3.12/lib/python/site...              mac
# 1  /Users/mac/Library/Python/3.12/lib/python/site...              mac
# 2  /Users/mac/Desktop/HW/.venv/lib/python3.10/sit...              mac
# 3  /Users/mac/Desktop/HW/.venv/lib/python3.10/sit...              mac
# 4  /Users/mac/Desktop/HW/.venv/lib/python3.10/sit...              mac
# 5  /Users/mac/Desktop/HW/.venv/lib/python3.10/sit...              mac
# 6  /Users/mac/Desktop/HW/.venv/lib/python3.10/sit...              mac
# 7  /Users/mac/Desktop/HW/.venv/lib/python3.10/sit...              mac
#
# [8 rows x 21 columns]

# %%
import mlflow

mlflow.set_tracking_uri(
    "sqlite:////Users/mac/Desktop/HW/State_Data/mlflow.db"
)
mlflow.set_experiment("core3_degradation_hierarchical")
# Out:
# 2025/12/26 04:00:58 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2025/12/26 04:00:58 INFO mlflow.store.db.utils: Updating database tables
# 2025/12/26 04:00:58 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2025/12/26 04:00:58 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2025/12/26 04:00:58 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2025/12/26 04:00:58 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2025/12/26 04:00:58 INFO mlflow.tracking.fluent: Experiment with name 'core3_degradation_hierarchical' does not exist. Creating a new experiment.
# <Experiment: artifact_location='/Users/mac/Desktop/HW/State_Data/core_3/mlruns/1', creation_time=1766689258057, experiment_id='1', last_update_time=1766689258057, lifecycle_stage='active', name='core3_degradation_hierarchical', tags={}>
