# %%
from sqlalchemy import create_engine
import pandas as pd

ENGINE_URL = "mysql+pymysql://health_user:strong_password_here@localhost:3306/HEALTH?charset=utf8mb4"
engine = create_engine(ENGINE_URL)

core5_df = pd.read_csv("../data_csv/core5_decision_log.csv")

core5_df.to_sql(
    "core5_decision_log",
    con=engine,
    if_exists="append",
    index=False
)

print("✅ Core 5 decision log MySQL 적재 완료")
# Out:
# ✅ Core 5 decision log MySQL 적재 완료

# %%
pd.read_sql(
    "SELECT COUNT(*) AS cnt FROM core5_decision_log;",
    con=engine
)
# Out:
#    cnt
# 0  943
